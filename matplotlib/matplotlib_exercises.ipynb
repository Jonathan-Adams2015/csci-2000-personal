# %% [markdown]
# # Matplotlib Exercises
# Here are some ploting exercises, try to do them using the provided hints (5 min for each).

# %% [markdown]
# ### Making matplotlib inline
# First we need to make matplotlib inline in order to embed plots into the web page:

# %%
# %matplotlib inline

# %% [markdown]
# ### Importing necessary modules
# We just import `numpy` and `pyplot` once to prevent redundancy for the rest of exercises:

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Regular Plot
# <img style="float: right;" src="images/plot_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right taking care of filled areas:
# ```python
# n = 256
# X = np.linspace(-np.pi,np.pi,n,endpoint=True)
# Y = np.sin(2*X)
#
# plt.plot (X, Y+1, color='blue', alpha=1.00)
# plt.plot (X, Y-1, color='blue', alpha=1.00)
# plt.show()
# ```
# ### _Hints_
# You need to use the [fill_between](http://matplotlib.sourceforge.net/api/pyplot_api.html#matplotlib.pyplot.fill_between) command.

# %%
n = 256
X = np.linspace(-np.pi,np.pi,n,endpoint=True)
Y = np.sin(2*X)

range = np.array([-2,-1])

plt.plot (X, Y+1, color='blue', alpha=1.00)
plt.fill_between(X,Y+1,1, color='blue', alpha = '0.4')
plt.plot (X, Y-1, color='blue', alpha=1.00)
plt.fill_between(X,Y-1,-1, color='blue', alpha =0.4)
plt.show()

#Can't fill between bounds

# %% [markdown]
# ## Scatter Plot
#
# <img style="float: right;" src="images/scatter_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right taking care of marker size, color and transparency.
#
# ```python
# n = 1024
# X = np.random.normal(0,1,n)
# Y = np.random.normal(0,1,n)
#
# plt.scatter(X,Y)
# plt.show()
# ```
#
# ### _Hints_
# Color is given by angle of (X,Y).

# %%
n = 1024
X = np.random.normal(0,1,n)
Y = np.random.normal(0,1,n)

theta = 2*np.pi*np.tan(X/Y)

plt.scatter(X,Y)
plt.colors = theta
plt.show()

# %% [markdown]
# ## Bar Plot
#
# <img style="float: right;" src="images/bar_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right by adding labels for red bars.
#
# ```python
# n = 12
# X = np.arange(n)
# Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
# Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
#
# plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
# plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')
#
# for x,y in zip(X,Y1):
#     plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
#
# plt.ylim(-1.25,+1.25)
# plt.show()
# ```
#
# ### _Hints_
# You need to take care of text alignment.

# %%
n = 12
X = np.arange(n)
Y1 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)
Y2 = (1-X/float(n)) * np.random.uniform(0.5,1.0,n)

plt.bar(X, +Y1, facecolor='#9999ff', edgecolor='white')
plt.bar(X, -Y2, facecolor='#ff9999', edgecolor='white')

for x,y in zip(X,Y1):
    plt.text(x+0.4, y+0.05, '%.2f' % y, ha='center', va= 'bottom')
    
for x,y in zip(X,Y2):
    plt.text(x+0.4, -y-0.2, '%.2f' % y, ha='center', va= 'bottom')

plt.ylim(-1.25,+1.25)
plt.show()

# %% [markdown]
# ## Contour Plot
#
# <img style="float: right;" src="images/contour_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right taking care of the colormap (see Colormaps below).
#
# ```python
# def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)
#
# n = 256
# x = np.linspace(-3,3,n)
# y = np.linspace(-3,3,n)
# X,Y = np.meshgrid(x,y)
#
# plt.contourf(X, Y, f(X,Y), 8, alpha=.75, cmap='jet')
# C = plt.contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
# plt.show()
# ```
#
# ### _Hints_
# You need to use the [clabel](http://matplotlib.sourceforge.net/api/pyplot_api.html#matplotlib.pyplot.clabel) command.

# %%
def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 256
x = np.linspace(-3,3,n)
y = np.linspace(-3,3,n)
X,Y = np.meshgrid(x,y)

plt.contourf(X, Y, f(X,Y), 8, alpha=0.75, cmap='afmhot')
C = plt.contour(X, Y, f(X,Y), 8, colors='black', linewidth=.5)
plt.clabel(C, inline=1, fontsize=10)
plt.show()

#Kinda pale

# %% [markdown]
# ## Imshow
#
# <img style="float: right;" src="images/imshow_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right taking care of colormap, image interpolation and origin.
#
# ```python
# def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)
#
# n = 10
# x = np.linspace(-3,3,4*n)
# y = np.linspace(-3,3,3*n)
# X,Y = np.meshgrid(x,y)
# plt.imshow(f(X,Y))
# plt.show()
# ```
#
# ### _Hints_
# You need to take care of the `origin` of the image in the imshow command and use a [colorbar](http://matplotlib.sourceforge.net/api/pyplot_api.html#matplotlib.pyplot.colorbar).

# %%
def f(x,y): return (1-x/2+x**5+y**3)*np.exp(-x**2-y**2)

n = 10
x = np.linspace(-3,3,4*n)
y = np.linspace(-3,3,3*n)
X,Y = np.meshgrid(x,y)
plt.gray()

plt.imshow(f(X,Y), interpolation="nearest")
plt.colorbar()
plt.show()

#In grayscale; no blue

# %% [markdown]
# ## Pie Chart
#
# <img style="float: right;" src="images/pie_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right taking care of colors and slices size.
#
# ```python
# n = 20
# Z = np.random.uniform(0,1,n)
# plt.pie(Z)
# plt.show()
# ```
#
# ### _Hints_
# You need to modify Z.

# %%
n = 20
Z = np.random.uniform(0,1,n)

plt.pie(Z, explode='0.1')
plt.show()
#Doesn't want to explode, can't get started on colors
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-57-bcb44a178c10> in <module>()
#       2 Z = np.random.uniform(0,1,n)
#       3
# ----> 4 plt.pie(Z, explode='0.1')
#       5 plt.show()
#       6 #Doesn't want to explode
#
# /home/jon/anaconda3/lib/python3.4/site-packages/matplotlib/pyplot.py in pie(x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops, hold)
#    3079                      labeldistance=labeldistance, startangle=startangle,
#    3080                      radius=radius, counterclock=counterclock,
# -> 3081                      wedgeprops=wedgeprops, textprops=textprops)
#    3082         draw_if_interactive()
#    3083     finally:
#
# /home/jon/anaconda3/lib/python3.4/site-packages/matplotlib/axes/_axes.py in pie(self, x, explode, labels, colors, autopct, pctdistance, shadow, labeldistance, startangle, radius, counterclock, wedgeprops, textprops)
#    2428             explode = [0] * len(x)
#    2429         assert(len(x) == len(labels))
# -> 2430         assert(len(x) == len(explode))
#    2431         if colors is None:
#    2432             colors = ('b', 'g', 'r', 'c', 'm', 'y', 'k', 'w')
#
# AssertionError:

# %% [markdown]
# ## Quiver Plot
#
# <img style="float: right;" src="images/quiver_ex.png" />
# Starting from the code above, try to reproduce the graphic on the right taking care of colors and orientations.
#
# ```python
# n = 8
# X,Y = np.mgrid[0:n,0:n]
# plt.quiver(X,Y)
# plt.show()
# ```
#
# ### _Hints_
# You need to draw arrows twice.

# %%
n = 8
X,Y = np.mgrid[0:n,0:n]
plt.quiver(X,Y)
plt.show()

# %% [markdown]
# ## Grid
#
# <img style="float: right;" src="images/grid_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right taking care of line styles.
#
# ```python
# axes = plt.gca()
# axes.set_xlim(0,4)
# axes.set_ylim(0,3)
# axes.set_xticklabels([])
# axes.set_yticklabels([])
#
# plt.show()
# ```

# %%
axes = plt.gca()
axes.set_xlim(0,4)
axes.set_ylim(0,3)
axes.set_xticklabels([])
axes.set_yticklabels([])
plt.grid(axes, b='on', which='both', axis='both')

plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-64-4e0845c3b553> in <module>()
#       4 axes.set_xticklabels([])
#       5 axes.set_yticklabels([])
# ----> 6 plt.grid(axes, b='on', which='major', axis='both')
#       7
#       8 plt.show()
#
# TypeError: grid() got multiple values for argument 'b'

# %% [markdown]
# ## Multi Plot
#
# <img style="float: right;" src="images/multiplot_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right.
#
# ```python
# plt.subplot(2,2,1)
# plt.subplot(2,2,3)
# plt.subplot(2,2,4)
#
# plt.show()
# ```
#
# ### _Hints_
# You can use several subplots with different partition.

# %% [markdown]
# ## Polar Axis
#
# <img style="float: right;" src="images/polar_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right.
#
# ```python
# plt.axes([0,0,1,1])
#
# N = 20
# theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
# radii = 10*np.random.rand(N)
# width = np.pi/4*np.random.rand(N)
# bars = plt.bar(theta, radii, width=width, bottom=0.0)
#
# for r,bar in zip(radii, bars):
#     bar.set_facecolor(plt.cm.jet(r/10.))
#     bar.set_alpha(0.5)
#
# plt.show()
# ```
#
# ### _Hints_
# You only need to modify the axes line.

# %%
plt.axes([0,0,1,1])

N = 20
theta = np.arange(0.0, 2*np.pi, 2*np.pi/N)
radii = 10*np.random.rand(N)
width = np.pi/4*np.random.rand(N)
bars = plt.bar(theta, radii, width=width, bottom=0.0)

for r,bar in zip(radii, bars):
    bar.set_facecolor(plt.cm.jet(r/10.))
    bar.set_alpha(0.5)


plt.show()

# %% [markdown]
# ## 3D Plot
#
# <img style="float: right;" src="images/plot3d_ex.png" />
# Starting from the code below, try to reproduce the graphic on the right.
#
# ```python
# from mpl_toolkits.mplot3d import Axes3D
#
# fig = plt.figure()
# ax = Axes3D(fig)
# X = np.arange(-4, 4, 0.25)
# Y = np.arange(-4, 4, 0.25)
# X, Y = np.meshgrid(X, Y)
# R = np.sqrt(X**2 + Y**2)
# Z = np.sin(R)
#
# ax.plot_surface(X, Y, Z, rstride=1, cstride=1, cmap='hot')
#
# plt.show()
# ```
#
# ### _Hints_
# You need to use [contourf](http://matplotlib.sourceforge.net/api/pyplot_api.html#matplotlib.pyplot.contourf).

# %% [markdown]
# ## Text
#
# <img style="float: right;" src="images/text_ex.png" />
# Try to do the same from scratch!
#
# ### _Hints_
# Have a look at the [matplotlib logo](http://matplotlib.sourceforge.net/examples/api/logo2.html).
